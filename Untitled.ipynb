# %%
#import requests
import requests
import json 
import pandas as pd

# %%
specie_lst = []
for p in range (6):
    url = "https://pokeapi.co/api/v2/growth-rate/"+str(p+1)
    response = requests.get(url).json()
    response["name"]

for specie in response["pokemon_species"]:
    print(specie["name"])
    specie_lst.append(specie)
    
len(specie_lst)
    

#inal = {"level": ["slow", "medium", "fast", "medium-slow", "slow-then-very-fast", "fast-then-very-slow"], "species": ["specie_A","specie_B","specie_C"]}
#inal_df = pd.DataFrame(final)
#rint(final_df)



#res = requests.get('https://pokeapi.co/api/v2/growth-rate')
#response = json.loads(res.text)
#print(response.json)
# Out:
# shroomish
# makuhita
# illumise
# gulpin
# wailmer
# seviper
# corphish
# drifloon
# breloom
# hariyama
# swalot
# wailord
# crawdaunt
# drifblim
# 14

# %%
url = "https://pokeapi.co/api/v2/growth-rate/1/"
response = requests.get(url).json()
response["name"]
for specie in response["pokemon_species"]:
    print(specie["name"])
final = {"level": ["slow", "slow", "slow"], "species": ["specie_A","specie_B","specie_C"]}
final_df = pd.DataFrame(final)
print(final_df)
# Out:
# growlithe
# tentacool
# shellder
# exeggcute
# rhyhorn
# staryu
# pinsir
# tauros
# magikarp
# lapras
# aerodactyl
# articuno
# zapdos
# moltres
# dratini
# mewtwo
# chinchou
# heracross
# swinub
# lanturn
# skarmory
# houndour
# stantler
# miltank
# raikou
# entei
# suicune
# larvitar
# lugia
# ho-oh
# ralts
# slakoth
# aron
# electrike
# carvanha
# tropius
# relicanth
# bagon
# beldum
# regirock
# regice
# registeel
# latias
# latios
# kyogre
# groudon
# rayquaza
# jirachi
# deoxys
# gible
# munchlax
# hippopotas
# skorupi
# carnivine
# mantyke
# snover
# uxie
# mesprit
# azelf
# dialga
# palkia
# heatran
# regigigas
# giratina
# cresselia
# phione
# manaphy
# darkrai
# arceus
# victini
# vanillite
# tynamo
# axew
# rufflet
# vullaby
# deino
# larvesta
# cobalion
# terrakion
# virizion
# tornadus
# thundurus
# reshiram
# zekrom
# landorus
# kyurem
# keldeo
# meloetta
# genesect
# clauncher
# carbink
# goomy
# xerneas
# yveltal
# zygarde
# diancie
# hoopa
# volcanion
# oranguru
# ...
